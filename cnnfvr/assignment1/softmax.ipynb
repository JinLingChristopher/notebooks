# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.380459
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 3.155987 analytic: 3.155987, relative error: 2.077253e-08
# numerical: 0.688058 analytic: 0.688058, relative error: 2.531784e-08
# numerical: 0.558921 analytic: 0.558921, relative error: 2.506002e-08
# numerical: 1.534996 analytic: 1.534995, relative error: 1.745236e-08
# numerical: -0.609101 analytic: -0.609101, relative error: 1.187939e-07
# numerical: 3.905345 analytic: 3.905345, relative error: 3.772795e-08
# numerical: 0.498781 analytic: 0.498781, relative error: 2.991851e-08
# numerical: 0.328720 analytic: 0.328720, relative error: 3.266821e-08
# numerical: 1.368060 analytic: 1.368059, relative error: 4.630647e-08
# numerical: 1.817777 analytic: 1.817777, relative error: 5.987036e-08
# numerical: 0.585336 analytic: 0.588633, relative error: 2.808199e-03
# numerical: -0.015391 analytic: -0.020194, relative error: 1.349813e-01
# numerical: 2.439286 analytic: 2.444797, relative error: 1.128368e-03
# numerical: -2.611350 analytic: -2.617387, relative error: 1.154573e-03
# numerical: 0.074813 analytic: 0.074141, relative error: 4.513941e-03
# numerical: -1.575311 analytic: -1.575148, relative error: 5.170125e-05
# numerical: -0.657369 analytic: -0.658495, relative error: 8.560692e-04
# numerical: 1.116701 analytic: 1.118424, relative error: 7.709304e-04
# numerical: -0.677841 analytic: -0.677709, relative error: 9.741097e-05
# numerical: -1.999121 analytic: -2.003279, relative error: 1.038885e-03

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.380459e+00 computed in 0.078134s
# vectorized loss: 2.380459e+00 computed in 0.000000s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 2e-7, 5e-7, 1e-6]
regularization_strengths = [1e4, 2.5e4, 5e4, 7e4, 1e5]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
def accuracy(y_pred, y_true):
    return np.mean(y_pred == y_true)

for rate in learning_rates:
    for strength in regularization_strengths:
        clf = Softmax()
        clf.train(X_train, y_train, learning_rate=rate, reg=strength, 
                  num_iters=1500, verbose=True)
        train_accuracy = accuracy(clf.predict(X_train), y_train)
        validation_accuracy = accuracy(clf.predict(X_val), y_val)
        
        results[(rate, strength)] = (train_accuracy, validation_accuracy)
        if validation_accuracy > best_val:
            best_val = validation_accuracy
            best_softmax = clf
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 316.962559
# iteration 100 / 1500: loss 257.725717
# iteration 200 / 1500: loss 210.795856
# iteration 300 / 1500: loss 172.485883
# iteration 400 / 1500: loss 141.152310
# iteration 500 / 1500: loss 115.513649
# iteration 600 / 1500: loss 94.963087
# iteration 700 / 1500: loss 77.946725
# iteration 800 / 1500: loss 64.047419
# iteration 900 / 1500: loss 52.703706
# iteration 1000 / 1500: loss 43.292317
# iteration 1100 / 1500: loss 35.896294
# iteration 1200 / 1500: loss 29.620559
# iteration 1300 / 1500: loss 24.704173
# iteration 1400 / 1500: loss 20.528360
# iteration 0 / 1500: loss 780.636415
# iteration 100 / 1500: loss 469.958656
# iteration 200 / 1500: loss 284.922771
# iteration 300 / 1500: loss 173.201011
# iteration 400 / 1500: loss 105.517124
# iteration 500 / 1500: loss 64.701694
# iteration 600 / 1500: loss 39.983710
# iteration 700 / 1500: loss 24.953730
# iteration 800 / 1500: loss 15.917309
# iteration 900 / 1500: loss 10.467739
# iteration 1000 / 1500: loss 7.215667
# iteration 1100 / 1500: loss 5.176126
# iteration 1200 / 1500: loss 3.999554
# iteration 1300 / 1500: loss 3.224072
# iteration 1400 / 1500: loss 2.764672
# iteration 0 / 1500: loss 1551.377079
# iteration 100 / 1500: loss 568.770542
# iteration 200 / 1500: loss 209.557244
# iteration 300 / 1500: loss 78.052514
# iteration 400 / 1500: loss 30.022354
# iteration 500 / 1500: loss 12.369507
# iteration 600 / 1500: loss 5.914731
# iteration 700 / 1500: loss 3.527575
# iteration 800 / 1500: loss 2.685783
# iteration 900 / 1500: loss 2.361393
# iteration 1000 / 1500: loss 2.259216
# iteration 1100 / 1500: loss 2.251088
# iteration 1200 / 1500: loss 2.103892
# iteration 1300 / 1500: loss 2.152662
# iteration 1400 / 1500: loss 2.162432
# iteration 0 / 1500: loss 2153.179692
# iteration 100 / 1500: loss 528.352955
# iteration 200 / 1500: loss 130.957077
# iteration 300 / 1500: loss 33.670724
# iteration 400 / 1500: loss 9.972685
# iteration 500 / 1500: loss 4.112645
# iteration 600 / 1500: loss 2.702865
# iteration 700 / 1500: loss 2.342757
# iteration 800 / 1500: loss 2.244199
# iteration 900 / 1500: loss 2.240419
# iteration 1000 / 1500: loss 2.222782
# iteration 1100 / 1500: loss 2.200080
# iteration 1200 / 1500: loss 2.231296
# iteration 1300 / 1500: loss 2.201283
# iteration 1400 / 1500: loss 2.231853
# iteration 0 / 1500: loss 3103.741047
# iteration 100 / 1500: loss 416.291985
# iteration 200 / 1500: loss 57.496314
# iteration 300 / 1500: loss 9.654162
# iteration 400 / 1500: loss 3.202146
# iteration 500 / 1500: loss 2.378564
# iteration 600 / 1500: loss 2.235961
# iteration 700 / 1500: loss 2.247370
# iteration 800 / 1500: loss 2.202483
# iteration 900 / 1500: loss 2.151340
# iteration 1000 / 1500: loss 2.211981
# iteration 1100 / 1500: loss 2.261375
# iteration 1200 / 1500: loss 2.245377
# iteration 1300 / 1500: loss 2.206284
# iteration 1400 / 1500: loss 2.205604
# iteration 0 / 1500: loss 310.195874
# iteration 100 / 1500: loss 205.804613
# iteration 200 / 1500: loss 138.056500
# iteration 300 / 1500: loss 92.634735
# iteration 400 / 1500: loss 62.563764
# iteration 500 / 1500: loss 42.344016
# iteration 600 / 1500: loss 29.009502
# iteration 700 / 1500: loss 20.011483
# iteration 800 / 1500: loss 14.066758
# iteration 900 / 1500: loss 10.032109
# iteration 1000 / 1500: loss 7.459300
# iteration 1100 / 1500: loss 5.672309
# iteration 1200 / 1500: loss 4.453459
# iteration 1300 / 1500: loss 3.559163
# iteration 1400 / 1500: loss 3.055699
# iteration 0 / 1500: loss 769.089861
# iteration 100 / 1500: loss 281.305722
# iteration 200 / 1500: loss 104.123568
# iteration 300 / 1500: loss 39.462514
# iteration 400 / 1500: loss 15.846751
# iteration 500 / 1500: loss 7.099319
# iteration 600 / 1500: loss 3.911732
# iteration 700 / 1500: loss 2.790457
# iteration 800 / 1500: loss 2.399214
# iteration 900 / 1500: loss 2.120631
# iteration 1000 / 1500: loss 2.190131
# iteration 1100 / 1500: loss 2.112240
# iteration 1200 / 1500: loss 2.117093
# iteration 1300 / 1500: loss 2.115195
# iteration 1400 / 1500: loss 2.090834
# iteration 0 / 1500: loss 1541.503514
# iteration 100 / 1500: loss 207.090676
# iteration 200 / 1500: loss 29.498387
# iteration 300 / 1500: loss 5.796973
# iteration 400 / 1500: loss 2.634382
# iteration 500 / 1500: loss 2.162021
# iteration 600 / 1500: loss 2.199139
# iteration 700 / 1500: loss 2.151285
# iteration 800 / 1500: loss 2.198135
# iteration 900 / 1500: loss 2.176433
# iteration 1000 / 1500: loss 2.184885
# iteration 1100 / 1500: loss 2.175048
# iteration 1200 / 1500: loss 2.224501
# iteration 1300 / 1500: loss 2.195311
# iteration 1400 / 1500: loss 2.207920
# iteration 0 / 1500: loss 2166.664391
# iteration 100 / 1500: loss 130.455788
# iteration 200 / 1500: loss 9.822926
# iteration 300 / 1500: loss 2.648825
# iteration 400 / 1500: loss 2.149980
# iteration 500 / 1500: loss 2.191832
# iteration 600 / 1500: loss 2.155933
# iteration 700 / 1500: loss 2.188131
# iteration 800 / 1500: loss 2.190061
# iteration 900 / 1500: loss 2.203076
# iteration 1000 / 1500: loss 2.136361
# iteration 1100 / 1500: loss 2.189178
# iteration 1200 / 1500: loss 2.181094
# iteration 1300 / 1500: loss 2.202016
# iteration 1400 / 1500: loss 2.212252
# iteration 0 / 1500: loss 3062.809277
# iteration 100 / 1500: loss 55.764864
# iteration 200 / 1500: loss 3.182799
# iteration 300 / 1500: loss 2.238836
# iteration 400 / 1500: loss 2.175812
# iteration 500 / 1500: loss 2.235734
# iteration 600 / 1500: loss 2.240283
# iteration 700 / 1500: loss 2.256444
# iteration 800 / 1500: loss 2.193382
# iteration 900 / 1500: loss 2.208035
# iteration 1000 / 1500: loss 2.247675
# iteration 1100 / 1500: loss 2.217927
# iteration 1200 / 1500: loss 2.191104
# iteration 1300 / 1500: loss 2.199568
# iteration 1400 / 1500: loss 2.212005
# iteration 0 / 1500: loss 315.438967
# iteration 100 / 1500: loss 115.052210
# iteration 200 / 1500: loss 43.225776
# iteration 300 / 1500: loss 17.072170
# iteration 400 / 1500: loss 7.470347
# iteration 500 / 1500: loss 4.012289
# iteration 600 / 1500: loss 2.795100
# iteration 700 / 1500: loss 2.236853
# iteration 800 / 1500: loss 2.127429
# iteration 900 / 1500: loss 2.118490
# iteration 1000 / 1500: loss 2.094988
# iteration 1100 / 1500: loss 2.004932
# iteration 1200 / 1500: loss 2.021011
# iteration 1300 / 1500: loss 2.147673
# iteration 1400 / 1500: loss 2.111295
# iteration 0 / 1500: loss 782.576809
# iteration 100 / 1500: loss 64.304694
# iteration 200 / 1500: loss 7.114768
# iteration 300 / 1500: loss 2.563523
# iteration 400 / 1500: loss 2.162106
# iteration 500 / 1500: loss 2.132430
# iteration 600 / 1500: loss 2.196652
# iteration 700 / 1500: loss 2.064338
# iteration 800 / 1500: loss 2.069171
# iteration 900 / 1500: loss 2.109908
# iteration 1000 / 1500: loss 2.183105
# iteration 1100 / 1500: loss 2.158472
# iteration 1200 / 1500: loss 2.118533
# iteration 1300 / 1500: loss 2.084597
# iteration 1400 / 1500: loss 2.111887
# iteration 0 / 1500: loss 1551.020024
# iteration 100 / 1500: loss 11.846905
# iteration 200 / 1500: loss 2.220953
# iteration 300 / 1500: loss 2.241541
# iteration 400 / 1500: loss 2.186709
# iteration 500 / 1500: loss 2.149881
# iteration 600 / 1500: loss 2.174378
# iteration 700 / 1500: loss 2.135457
# iteration 800 / 1500: loss 2.157965
# iteration 900 / 1500: loss 2.182671
# iteration 1000 / 1500: loss 2.184596
# iteration 1100 / 1500: loss 2.197042
# iteration 1200 / 1500: loss 2.223972
# iteration 1300 / 1500: loss 2.177663
# iteration 1400 / 1500: loss 2.176432
# iteration 0 / 1500: loss 2127.319774
# iteration 100 / 1500: loss 3.919866
# iteration 200 / 1500: loss 2.201923
# iteration 300 / 1500: loss 2.206334
# iteration 400 / 1500: loss 2.211151
# iteration 500 / 1500: loss 2.235171
# iteration 600 / 1500: loss 2.227807
# iteration 700 / 1500: loss 2.189058
# iteration 800 / 1500: loss 2.235152
# iteration 900 / 1500: loss 2.186947
# iteration 1000 / 1500: loss 2.203967
# iteration 1100 / 1500: loss 2.207298
# iteration 1200 / 1500: loss 2.234674
# iteration 1300 / 1500: loss 2.251024
# iteration 1400 / 1500: loss 2.233484
# iteration 0 / 1500: loss 3118.310813
# iteration 100 / 1500: loss 2.376293
# iteration 200 / 1500: loss 2.247471
# iteration 300 / 1500: loss 2.249340
# iteration 400 / 1500: loss 2.249572
# iteration 500 / 1500: loss 2.189650
# iteration 600 / 1500: loss 2.256344
# iteration 700 / 1500: loss 2.244139
# iteration 800 / 1500: loss 2.220497
# iteration 900 / 1500: loss 2.231730
# iteration 1000 / 1500: loss 2.263701
# iteration 1100 / 1500: loss 2.247527
# iteration 1200 / 1500: loss 2.234171
# iteration 1300 / 1500: loss 2.216061
# iteration 1400 / 1500: loss 2.195788
# iteration 0 / 1500: loss 312.132963
# iteration 100 / 1500: loss 42.598435
# iteration 200 / 1500: loss 7.386320
# iteration 300 / 1500: loss 2.744194
# iteration 400 / 1500: loss 2.139351
# iteration 500 / 1500: loss 1.993652
# iteration 600 / 1500: loss 2.012085
# iteration 700 / 1500: loss 2.039033
# iteration 800 / 1500: loss 2.029073
# iteration 900 / 1500: loss 2.066245
# iteration 1000 / 1500: loss 2.081333
# iteration 1100 / 1500: loss 2.057749
# iteration 1200 / 1500: loss 1.978596
# iteration 1300 / 1500: loss 1.950838
# iteration 1400 / 1500: loss 2.107918
# iteration 0 / 1500: loss 773.578250
# iteration 100 / 1500: loss 6.855487
# iteration 200 / 1500: loss 2.126168
# iteration 300 / 1500: loss 2.131386
# iteration 400 / 1500: loss 2.072807
# iteration 500 / 1500: loss 2.185463
# iteration 600 / 1500: loss 2.164235
# iteration 700 / 1500: loss 2.156355
# iteration 800 / 1500: loss 2.168472
# iteration 900 / 1500: loss 2.134572
# iteration 1000 / 1500: loss 2.198683
# iteration 1100 / 1500: loss 2.146716
# iteration 1200 / 1500: loss 2.092203
# iteration 1300 / 1500: loss 2.089675
# iteration 1400 / 1500: loss 2.149019
# iteration 0 / 1500: loss 1546.477208
# iteration 100 / 1500: loss 2.266804
# iteration 200 / 1500: loss 2.196894
# iteration 300 / 1500: loss 2.197671
# iteration 400 / 1500: loss 2.171822
# iteration 500 / 1500: loss 2.172665
# iteration 600 / 1500: loss 2.184140
# iteration 700 / 1500: loss 2.106949
# iteration 800 / 1500: loss 2.219390
# iteration 900 / 1500: loss 2.213694
# iteration 1000 / 1500: loss 2.219870
# iteration 1100 / 1500: loss 2.147151
# iteration 1200 / 1500: loss 2.187562
# iteration 1300 / 1500: loss 2.190835
# iteration 1400 / 1500: loss 2.141833
# iteration 0 / 1500: loss 2188.559814
# iteration 100 / 1500: loss 2.245214
# iteration 200 / 1500: loss 2.173335
# iteration 300 / 1500: loss 2.225322
# iteration 400 / 1500: loss 2.203273
# iteration 500 / 1500: loss 2.209755
# iteration 600 / 1500: loss 2.237427
# iteration 700 / 1500: loss 2.220787
# iteration 800 / 1500: loss 2.178477
# iteration 900 / 1500: loss 2.198951
# iteration 1000 / 1500: loss 2.253466
# iteration 1100 / 1500: loss 2.207393
# iteration 1200 / 1500: loss 2.183385
# iteration 1300 / 1500: loss 2.214227
# iteration 1400 / 1500: loss 2.157289
# iteration 0 / 1500: loss 3093.735093
# iteration 100 / 1500: loss 2.210381
# iteration 200 / 1500: loss 2.251509
# iteration 300 / 1500: loss 2.225170
# iteration 400 / 1500: loss 2.232152
# iteration 500 / 1500: loss 2.225818
# iteration 600 / 1500: loss 2.240474
# iteration 700 / 1500: loss 2.167428
# iteration 800 / 1500: loss 2.270484
# iteration 900 / 1500: loss 2.288562
# iteration 1000 / 1500: loss 2.234758
# iteration 1100 / 1500: loss 2.208419
# iteration 1200 / 1500: loss 2.246665
# iteration 1300 / 1500: loss 2.280668
# iteration 1400 / 1500: loss 2.303673
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.328020 val accuracy: 0.341000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.353633 val accuracy: 0.365000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.322816 val accuracy: 0.341000
# lr 1.000000e-07 reg 7.000000e+04 train accuracy: 0.324918 val accuracy: 0.337000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.300755 val accuracy: 0.318000
# lr 2.000000e-07 reg 1.000000e+04 train accuracy: 0.368673 val accuracy: 0.373000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.353612 val accuracy: 0.364000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.330347 val accuracy: 0.341000
# lr 2.000000e-07 reg 7.000000e+04 train accuracy: 0.317837 val accuracy: 0.336000
# lr 2.000000e-07 reg 1.000000e+05 train accuracy: 0.312939 val accuracy: 0.323000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.372041 val accuracy: 0.377000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.336265 val accuracy: 0.350000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.323469 val accuracy: 0.340000
# lr 5.000000e-07 reg 7.000000e+04 train accuracy: 0.316408 val accuracy: 0.320000
# lr 5.000000e-07 reg 1.000000e+05 train accuracy: 0.311714 val accuracy: 0.322000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.368592 val accuracy: 0.367000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.337102 val accuracy: 0.358000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.327939 val accuracy: 0.351000
# lr 1.000000e-06 reg 7.000000e+04 train accuracy: 0.317633 val accuracy: 0.333000
# lr 1.000000e-06 reg 1.000000e+05 train accuracy: 0.288878 val accuracy: 0.304000
# best validation accuracy achieved during cross-validation: 0.377000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.374000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
